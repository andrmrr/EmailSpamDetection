# %% [markdown]
# # MLP

# %%
import os
import joblib
import json
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, classification_report

from sklearn.neural_network import MLPClassifier

# %%
base_dir = os.getcwd()
datafile = os.path.join(base_dir, "data", "data_cleaned.csv")

# %%
df = pd.read_csv(datafile, index_col=None)
df.head()
# Out:
#    label                                             tokens
# 0      0  ["'hpl", 'nom', 'may', 'see', 'attached', 'fil...
# 1      0  ["'nom", 'actual', 'vols', 'th', 'forwarded', ...
# 2      0  ["'enron", 'actuals', 'march', 'april', 'estim...
# 3      0  ["'hpl", 'nom', 'may', 'see', 'attached', 'fil...
# 4      0  ["'hpl", 'nom', 'june', 'see', 'attached', 'fi...

# %%
train_df, test_df = train_test_split(df, test_size=0.3, random_state=33)
x_train = train_df['tokens']
x_test = test_df['tokens']
y_train = train_df['label']
y_test = test_df['label']

# %% [markdown]
# ## Train and grid-search MLP parameters using BOW

# %%
vectorizer = CountVectorizer(lowercase=True, stop_words='english', max_features=100000)
x_train_bow = vectorizer.fit_transform(x_train)
x_test_bow  = vectorizer.transform(x_test)

# %%
param_grid = {
    'hidden_layer_sizes': [(128,), (128, 64), (256, 128)],
    'activation': ['relu', 'tanh'],
    'solver': ['adam', 'sgd'],
    'learning_rate': ['constant'] #, 'adaptive']
}

# %%
mlp = MLPClassifier(max_iter=200, random_state=17)
grid = GridSearchCV(mlp, param_grid, cv=5, scoring='accuracy', verbose=2, n_jobs=-1)
grid.fit(x_train_bow, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] END activation=relu, hidden_layer_sizes=(128,), learning_rate=constant, solver=adam; total time=39.6min
# [CV] END activation=relu, hidden_layer_sizes=(128,), learning_rate=constant, solver=adam; total time=43.6min
# [CV] END activation=relu, hidden_layer_sizes=(128,), learning_rate=constant, solver=adam; total time=47.9min
# [CV] END activation=relu, hidden_layer_sizes=(128,), learning_rate=constant, solver=adam; total time=58.5min
# [CV] END activation=relu, hidden_layer_sizes=(128,), learning_rate=constant, solver=adam; total time=68.2min
# [CV] END activation=relu, hidden_layer_sizes=(128, 64), learning_rate=constant, solver=adam; total time=33.4min
# [CV] END activation=relu, hidden_layer_sizes=(128, 64), learning_rate=constant, solver=adam; total time=34.7min
# [CV] END activation=relu, hidden_layer_sizes=(128, 64), learning_rate=constant, solver=adam; total time=34.6min
# [CV] END activation=relu, hidden_layer_sizes=(128, 64), learning_rate=constant, solver=adam; total time=46.7min
# [CV] END activation=relu, hidden_layer_sizes=(128, 64), learning_rate=constant, solver=adam; total time=45.4min
# [CV] END activation=relu, hidden_layer_sizes=(128,), learning_rate=constant, solver=sgd; total time=225.6min
# [CV] END activation=relu, hidden_layer_sizes=(128,), learning_rate=constant, solver=sgd; total time=230.5min
# [CV] END activation=relu, hidden_layer_sizes=(128,), learning_rate=constant, solver=sgd; total time=234.0min
# [CV] END activation=relu, hidden_layer_sizes=(128, 64), learning_rate=constant, solver=sgd; total time=144.6min
# [CV] END activation=relu, hidden_layer_sizes=(128, 64), learning_rate=constant, solver=sgd; total time=138.2min
# [CV] END activation=relu, hidden_layer_sizes=(128,), learning_rate=constant, solver=sgd; total time=231.1min
# [CV] END activation=relu, hidden_layer_sizes=(128,), learning_rate=constant, solver=sgd; total time=228.9min
# [CV] END activation=relu, hidden_layer_sizes=(128, 64), learning_rate=constant, solver=sgd; total time=137.7min
# [CV] END activation=relu, hidden_layer_sizes=(256, 128), learning_rate=constant, solver=adam; total time=92.4min
# [CV] END activation=relu, hidden_layer_sizes=(256, 128), learning_rate=constant, solver=adam; total time=81.5min
# [CV] END activation=relu, hidden_layer_sizes=(256, 128), learning_rate=constant, solver=adam; total time=77.3min
# [CV] END activation=relu, hidden_layer_sizes=(128, 64), learning_rate=constant, solver=sgd; total time=119.6min
# [CV] END activation=relu, hidden_layer_sizes=(256, 128), learning_rate=constant, solver=adam; total time=76.6min
# [CV] END activation=relu, hidden_layer_sizes=(128, 64), learning_rate=constant, solver=sgd; total time=119.6min
# [CV] END activation=relu, hidden_layer_sizes=(256, 128), learning_rate=constant, solver=adam; total time=98.8min
# [CV] END activation=tanh, hidden_layer_sizes=(128,), learning_rate=constant, solver=adam; total time=30.9min
# [CV] END activation=tanh, hidden_layer_sizes=(128,), learning_rate=constant, solver=adam; total time=33.9min
# [CV] END activation=tanh, hidden_layer_sizes=(128,), learning_rate=constant, solver=adam; total time=28.9min
# [CV] END activation=tanh, hidden_layer_sizes=(128,), learning_rate=constant, solver=adam; total time=30.1min
# [CV] END activation=tanh, hidden_layer_sizes=(128,), learning_rate=constant, solver=adam; total time=34.8min
# [CV] END activation=tanh, hidden_layer_sizes=(128,), learning_rate=constant, solver=sgd; total time=187.5min
# [CV] END activation=tanh, hidden_layer_sizes=(128,), learning_rate=constant, solver=sgd; total time=184.9min
# [CV] END activation=relu, hidden_layer_sizes=(256, 128), learning_rate=constant, solver=sgd; total time=324.4min
# [CV] END activation=tanh, hidden_layer_sizes=(128,), learning_rate=constant, solver=sgd; total time=187.6min
# [CV] END activation=tanh, hidden_layer_sizes=(128, 64), learning_rate=constant, solver=adam; total time=28.3min
# [CV] END activation=tanh, hidden_layer_sizes=(128, 64), learning_rate=constant, solver=adam; total time=39.9min
# [CV] END activation=relu, hidden_layer_sizes=(256, 128), learning_rate=constant, solver=sgd; total time=319.3min
# [CV] END activation=relu, hidden_layer_sizes=(256, 128), learning_rate=constant, solver=sgd; total time=318.7min
# [CV] END activation=relu, hidden_layer_sizes=(256, 128), learning_rate=constant, solver=sgd; total time=313.2min
# [CV] END activation=relu, hidden_layer_sizes=(256, 128), learning_rate=constant, solver=sgd; total time=313.8min
# [CV] END activation=tanh, hidden_layer_sizes=(128, 64), learning_rate=constant, solver=adam; total time=31.1min
# [CV] END activation=tanh, hidden_layer_sizes=(128, 64), learning_rate=constant, solver=adam; total time=41.0min
# [CV] END activation=tanh, hidden_layer_sizes=(128, 64), learning_rate=constant, solver=adam; total time=36.2min
# [CV] END activation=tanh, hidden_layer_sizes=(256, 128), learning_rate=constant, solver=adam; total time=83.2min
# [CV] END activation=tanh, hidden_layer_sizes=(128, 64), learning_rate=constant, solver=sgd; total time=132.5min
# [CV] END activation=tanh, hidden_layer_sizes=(128, 64), learning_rate=constant, solver=sgd; total time=129.8min
# [CV] END activation=tanh, hidden_layer_sizes=(128, 64), learning_rate=constant, solver=sgd; total time=130.8min
# [CV] END activation=tanh, hidden_layer_sizes=(128, 64), learning_rate=constant, solver=sgd; total time=130.9min
# [CV] END activation=tanh, hidden_layer_sizes=(128,), learning_rate=constant, solver=sgd; total time=212.2min
# [CV] END activation=tanh, hidden_layer_sizes=(128,), learning_rate=constant, solver=sgd; total time=208.5min
# [CV] END activation=tanh, hidden_layer_sizes=(128, 64), learning_rate=constant, solver=sgd; total time=127.4min
# [CV] END activation=tanh, hidden_layer_sizes=(256, 128), learning_rate=constant, solver=adam; total time=68.5min
# [CV] END activation=tanh, hidden_layer_sizes=(256, 128), learning_rate=constant, solver=adam; total time=73.9min
# [CV] END activation=tanh, hidden_layer_sizes=(256, 128), learning_rate=constant, solver=adam; total time=68.5min
# [CV] END activation=tanh, hidden_layer_sizes=(256, 128), learning_rate=constant, solver=adam; total time=67.5min
# [CV] END activation=tanh, hidden_layer_sizes=(256, 128), learning_rate=constant, solver=sgd; total time=210.7min
# [CV] END activation=tanh, hidden_layer_sizes=(256, 128), learning_rate=constant, solver=sgd; total time=208.5min
# [CV] END activation=tanh, hidden_layer_sizes=(256, 128), learning_rate=constant, solver=sgd; total time=200.9min
# [CV] END activation=tanh, hidden_layer_sizes=(256, 128), learning_rate=constant, solver=sgd; total time=207.9min
# [CV] END activation=tanh, hidden_layer_sizes=(256, 128), learning_rate=constant, solver=sgd; total time=187.0min
# GridSearchCV(cv=5, estimator=MLPClassifier(random_state=17), n_jobs=-1,
#              param_grid={'activation': ['relu', 'tanh'],
#                          'hidden_layer_sizes': [(128,), (128, 64), (256, 128)],
#                          'learning_rate': ['constant'],
#                          'solver': ['adam', 'sgd']},
#              scoring='accuracy', verbose=2)

# %%
print("Best Parameters:", grid.best_params_)
print("Best Cross-Validation Accuracy:", grid.best_score_)

# Evaluate best model
best_mlp = grid.best_estimator_
y_pred = best_mlp.predict(x_test_bow)
print(classification_report(y_test, y_pred))
# Out:
# Best Parameters: {'activation': 'relu', 'hidden_layer_sizes': (256, 128), 'learning_rate': 'constant', 'solver': 'adam'}
# Best Cross-Validation Accuracy: 0.9880671977831659
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     11951
#            1       0.99      0.99      0.99     12795
#
#     accuracy                           0.99     24746
#    macro avg       0.99      0.99      0.99     24746
# weighted avg       0.99      0.99      0.99     24746

# %% [markdown]
# ### Save the model and best params

# %%
joblib.dump(best_mlp, os.path.join(base_dir, 'models', 'MLP.joblib'))
with open(os.path.join(base_dir, 'models', 'MLP.json'), 'w') as f:
    f.write(json.dumps(grid.best_params_))

# %% [markdown]
# ## Train and MLP using best parameters on TF-IDF

# %%
tfidf_vectorizer = TfidfVectorizer(ngram_range=(1, 1), lowercase=True, stop_words='english', max_features=100000)
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)

# %%
# load best params from file
with open(os.path.join(base_dir, "models", "MLP.json"), "r") as f:
    best_params = json.load(f)

# %%
mlp = MLPClassifier(max_iter=200, random_state=17, **best_params)
mlp.fit(x_train_tfidf, y_train)

y_pred = mlp.predict(x_test_tfidf)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     11951
#            1       0.99      0.99      0.99     12795
#
#     accuracy                           0.99     24746
#    macro avg       0.99      0.99      0.99     24746
# weighted avg       0.99      0.99      0.99     24746

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Test Accuracy:", accuracy)
# Out:
# Test Accuracy: 0.9867049220075972

# %%
joblib.dump(mlp, os.path.join(base_dir, 'models', 'MLP_TFIDF.joblib'))
# Out:
# ['/Users/aki/Master/Advanced Machine Learning/Project/aml_spam/models/MLP_TFIDF.joblib']
