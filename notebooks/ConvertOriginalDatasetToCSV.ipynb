# %%
# from google.colab import drive
# drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data = []
columns = []
inside_data = False

with open('D://ML//AML//data//dataset_', "r", encoding="utf-8") as f:
    data_started = False
    for line in f:
      # remove the header
      if not data_started:
        if line.startswith("@ATTRIBUTE"):
          line_parts = line.split()
          columns.append(line_parts[1])
        elif line == "@DATA\n":
          data_started = True
      else: # actual data
        data.append(line.split(","))

df = pd.DataFrame(data, columns=columns)

# Convert numeric columns to appropriate types
for col in df.columns:
    try:
        df[col] = pd.to_numeric(df[col])
    except ValueError:
        pass

# %%
df.head()
# Out:
#                                        text_combined  label
# 0  'hpl nom may 25 2001 see attached file hplno 5...      0
# 1  'nom actual vols 24 th forwarded sabrae zajac ...      0
# 2  'enron actuals march 30 april 1 201 estimated ...      0
# 3  'hpl nom may 30 2001 see attached file hplno 5...      0
# 4  'hpl nom june 1 2001 see attached file hplno 6...      0

# %%
df.to_csv("D:\\ML\\AML\\data\\data.csv")
