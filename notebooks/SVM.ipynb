# %% [markdown]
# # SVM methods

# %%
import os
import joblib
import json
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, classification_report

from sklearn.svm import SVC

# %%
base_dir = os.getcwd()
datafile = os.path.join(base_dir, "data", "data_cleaned.csv")

# %%
df = pd.read_csv(datafile, index_col=None)
df.head()
# Out:
#    label                                             tokens   numbers  has_url
# 0      0  ["'hpl", 'nom', 'may', 'see', 'attached', 'fil...  0.266667    False
# 1      0  ["'nom", 'actual', 'vols', 'th', 'forwarded', ...  0.267943     True
# 2      0  ["'enron", 'actuals', 'march', 'april', 'estim...  0.379310    False
# 3      0  ["'hpl", 'nom', 'may', 'see', 'attached', 'fil...  0.266667    False
# 4      0  ["'hpl", 'nom', 'june', 'see', 'attached', 'fi...  0.266667    False

# %%
train_df, test_df = train_test_split(df, test_size=0.3, random_state=33)
x_train = train_df['tokens']
x_test = test_df['tokens']
y_train = train_df['label']
y_test = test_df['label']

# %%
vectorizer = CountVectorizer(lowercase=True, stop_words='english', max_features=100000)
x_train_bow = vectorizer.fit_transform(x_train)
x_test_bow  = vectorizer.transform(x_test)

# %%
x_train_bow.shape
# Out:
# (57740, 100000)

# %% [markdown]
# ## Train and grid-search SVM parameters

# %%
param_grid = {
    'C': [0.1, 1, 10, 100],
    'gamma': [1, 0.1, 0.01, 0.001],
    'kernel': ['rbf', 'linear']
}

# %%
svc = SVC()
grid = GridSearchCV(svc, param_grid, cv=5, scoring='accuracy', verbose=2, n_jobs=-1)
grid.fit(x_train_bow, y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV] END ......................C=0.1, gamma=1, kernel=linear; total time= 5.7min
# [CV] END ......................C=0.1, gamma=1, kernel=linear; total time= 7.6min
# [CV] END ......................C=0.1, gamma=1, kernel=linear; total time= 7.6min
# [CV] END ......................C=0.1, gamma=1, kernel=linear; total time= 5.9min
# [CV] END ......................C=0.1, gamma=1, kernel=linear; total time= 5.8min
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=22.1min
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=22.2min
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=22.2min
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=22.2min
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=22.2min
# [CV] END ....................C=0.1, gamma=0.1, kernel=linear; total time= 5.8min
# [CV] END ....................C=0.1, gamma=0.1, kernel=linear; total time= 7.6min
# [CV] END ....................C=0.1, gamma=0.1, kernel=linear; total time= 7.7min
# [CV] END ....................C=0.1, gamma=0.1, kernel=linear; total time= 6.0min
# [CV] END ....................C=0.1, gamma=0.1, kernel=linear; total time= 6.0min
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=28.7min
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=29.0min
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=59.3min
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=34.7min
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=60.0min
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=60.0min
# [CV] END ...................C=0.1, gamma=0.01, kernel=linear; total time= 8.3min
# [CV] END ...................C=0.1, gamma=0.01, kernel=linear; total time= 8.2min
# [CV] END ...................C=0.1, gamma=0.01, kernel=linear; total time= 6.0min
# [CV] END ...................C=0.1, gamma=0.01, kernel=linear; total time= 6.3min
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=59.3min
# [CV] END ...................C=0.1, gamma=0.01, kernel=linear; total time= 6.3min
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=59.6min
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=30.5min
# [CV] END ..................C=0.1, gamma=0.001, kernel=linear; total time= 7.9min
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=13.6min
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=13.4min
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=13.5min
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=13.3min
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=13.5min
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=30.4min
# [CV] END ..................C=0.1, gamma=0.001, kernel=linear; total time= 6.0min
# [CV] END ..................C=0.1, gamma=0.001, kernel=linear; total time= 6.2min
# [CV] END ..................C=0.1, gamma=0.001, kernel=linear; total time= 8.0min
# [CV] END ..................C=0.1, gamma=0.001, kernel=linear; total time= 6.1min
# [CV] END ........................C=1, gamma=1, kernel=linear; total time= 5.7min
# [CV] END ........................C=1, gamma=1, kernel=linear; total time= 7.8min
# [CV] END ........................C=1, gamma=1, kernel=linear; total time= 8.0min
# [CV] END ........................C=1, gamma=1, kernel=linear; total time= 6.1min
# [CV] END ........................C=1, gamma=1, kernel=linear; total time= 8.2min
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=48.6min
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=52.2min
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=52.4min
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=54.2min
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=54.0min
# [CV] END ......................C=1, gamma=0.1, kernel=linear; total time= 5.8min
# [CV] END ......................C=1, gamma=0.1, kernel=linear; total time= 7.8min
# /Users/aki/Library/Python/3.11/lib/python/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END ......................C=1, gamma=0.1, kernel=linear; total time= 8.0min
# [CV] END ......................C=1, gamma=0.1, kernel=linear; total time= 5.7min
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=57.3min
# [CV] END ......................C=1, gamma=0.1, kernel=linear; total time= 7.7min
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=61.6min
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=62.9min
# [CV] END .....................C=1, gamma=0.01, kernel=linear; total time= 7.5min
# [CV] END .....................C=1, gamma=0.01, kernel=linear; total time= 5.6min
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=36.8min
# [CV] END .....................C=1, gamma=0.01, kernel=linear; total time= 7.7min
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=55.4min
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=37.2min
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=36.3min
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=36.8min
# [CV] END .....................C=1, gamma=0.01, kernel=linear; total time= 6.0min
# [CV] END .....................C=1, gamma=0.01, kernel=linear; total time= 7.9min
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=56.8min
# [CV] END ....................C=1, gamma=0.001, kernel=linear; total time= 5.3min
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=36.4min
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=10.2min
# [CV] END ....................C=1, gamma=0.001, kernel=linear; total time= 7.2min
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=10.3min
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=10.1min
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time= 9.9min
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=12.3min
# [CV] END ....................C=1, gamma=0.001, kernel=linear; total time= 5.8min
# [CV] END ....................C=1, gamma=0.001, kernel=linear; total time= 7.8min
# [CV] END ....................C=1, gamma=0.001, kernel=linear; total time= 7.7min
# [CV] END .......................C=10, gamma=1, kernel=linear; total time= 5.6min
# [CV] END .......................C=10, gamma=1, kernel=linear; total time= 7.2min
# [CV] END .......................C=10, gamma=1, kernel=linear; total time= 7.1min
# [CV] END .......................C=10, gamma=1, kernel=linear; total time= 7.1min
# [CV] END .......................C=10, gamma=1, kernel=linear; total time= 7.4min
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=55.0min
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=58.6min
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=60.3min
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=58.9min
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=60.1min
# [CV] END .....................C=10, gamma=0.1, kernel=linear; total time= 5.6min
# [CV] END .....................C=10, gamma=0.1, kernel=linear; total time= 7.2min
# [CV] END .....................C=10, gamma=0.1, kernel=linear; total time= 6.9min
# [CV] END .....................C=10, gamma=0.1, kernel=linear; total time= 6.9min
# [CV] END .....................C=10, gamma=0.1, kernel=linear; total time= 7.0min
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=74.9min
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=74.3min
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=75.1min
# [CV] END ....................C=10, gamma=0.01, kernel=linear; total time= 5.3min
# [CV] END ....................C=10, gamma=0.01, kernel=linear; total time= 6.9min
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=42.7min
# [CV] END ....................C=10, gamma=0.01, kernel=linear; total time= 6.7min
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=42.1min
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=42.6min
# [CV] END ....................C=10, gamma=0.01, kernel=linear; total time= 6.7min
# [CV] END ....................C=10, gamma=0.01, kernel=linear; total time= 6.9min
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time= 9.4min
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time= 9.3min
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time= 9.5min
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=73.5min
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time= 9.5min
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=42.5min
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=73.2min
# [CV] END ...................C=10, gamma=0.001, kernel=linear; total time= 5.4min
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time= 9.3min
# [CV] END ...................C=10, gamma=0.001, kernel=linear; total time= 7.0min
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=41.8min
# [CV] END ...................C=10, gamma=0.001, kernel=linear; total time= 6.9min
# [CV] END ...................C=10, gamma=0.001, kernel=linear; total time= 6.9min
# [CV] END ...................C=10, gamma=0.001, kernel=linear; total time= 7.0min
# [CV] END ......................C=100, gamma=1, kernel=linear; total time= 4.7min
# [CV] END ......................C=100, gamma=1, kernel=linear; total time= 4.8min
# [CV] END ......................C=100, gamma=1, kernel=linear; total time= 4.9min
# [CV] END ......................C=100, gamma=1, kernel=linear; total time= 5.0min
# [CV] END ......................C=100, gamma=1, kernel=linear; total time= 6.6min
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=54.0min
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=57.7min
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=57.9min
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=59.3min
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=59.2min
# [CV] END ....................C=100, gamma=0.1, kernel=linear; total time= 4.8min
# [CV] END ....................C=100, gamma=0.1, kernel=linear; total time= 4.9min
# [CV] END ....................C=100, gamma=0.1, kernel=linear; total time= 4.9min
# [CV] END ....................C=100, gamma=0.1, kernel=linear; total time= 4.9min
# [CV] END ....................C=100, gamma=0.1, kernel=linear; total time= 6.4min
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=74.0min
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=73.8min
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=74.4min
# [CV] END ...................C=100, gamma=0.01, kernel=linear; total time= 4.6min
# [CV] END ...................C=100, gamma=0.01, kernel=linear; total time= 4.8min
# [CV] END ...................C=100, gamma=0.01, kernel=linear; total time= 4.7min
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=41.6min
# [CV] END ...................C=100, gamma=0.01, kernel=linear; total time= 5.0min
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=41.1min
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=41.4min
# [CV] END ...................C=100, gamma=0.01, kernel=linear; total time= 6.4min
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time= 9.0min
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time= 9.0min
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time= 8.9min
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time= 8.9min
# [CV] END ..................C=100, gamma=0.001, kernel=linear; total time= 4.7min
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=41.1min
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=40.4min
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=73.0min
# [CV] END ..................C=100, gamma=0.001, kernel=linear; total time= 4.9min
# [CV] END ..................C=100, gamma=0.001, kernel=linear; total time= 4.9min
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time= 8.7min
# [CV] END ..................C=100, gamma=0.001, kernel=linear; total time= 4.5min
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=72.5min
# [CV] END ..................C=100, gamma=0.001, kernel=linear; total time= 4.7min
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100], 'gamma': [1, 0.1, 0.01, 0.001],
#                          'kernel': ['rbf', 'linear']},
#              scoring='accuracy', verbose=2)

# %%
print("Best Parameters:", grid.best_params_)
print("Best Cross-Validation Accuracy:", grid.best_score_)

best_svc = grid.best_estimator_
y_pred = best_svc.predict(x_test_bow)
print(classification_report(y_test, y_pred))
# Out:
# Best Parameters: {'C': 0.1, 'gamma': 1, 'kernel': 'linear'}
# Best Cross-Validation Accuracy: 0.982074818150329
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98     11951
#            1       0.98      0.99      0.98     12795
#
#     accuracy                           0.98     24746
#    macro avg       0.98      0.98      0.98     24746
# weighted avg       0.98      0.98      0.98     24746

# %% [markdown]
# ### Save the model and best params

# %%
joblib.dump(best_svc, os.path.join(base_dir, 'models', 'SVC.joblib'))
with open(os.path.join(base_dir, 'models', 'SVC.json'), 'w') as f:
    f.write(json.dumps(grid.best_params_))
